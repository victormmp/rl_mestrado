# %%
import datetime
import os
from random import shuffle
import traceback
from typing import Union, List
import numpy as np
import pickle

import pandas as pd
from pypfopt import EfficientFrontier
from pypfopt import risk_models
from pypfopt import expected_returns
from pypfopt import plotting
from pypfopt.efficient_frontier import EfficientFrontier

from pypfopt import EfficientSemivariance
#from pypfopt import EfficientCVaR

from rl.Stock import Stock
import ffn.core as ffn
import bt

from tsmoothie.smoother import *

import matplotlib.pyplot as plt
plt.style.use('ggplot')
# plots of BT only work with this following command
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_6893/3846565167.py in <module>
#      17 #from pypfopt import EfficientCVaR
#      18
# ---> 19 from Modules.Stock import Stock
#      20 import ffn.core as ffn
#      21 import bt
#
# ModuleNotFoundError: No module named 'Modules'

# %%
def save_to_pickle(path, variables):
    """Salva variáveis em arquivo .pickle
    
    Arguments:
        path {str}-- Caminho do arquivo 
        variables {list} -- Lista de variáveis a serem salvas 
    """
    with open(path, 'wb') as f:
        pickle.dump(variables, f)

def return_from_pickle(path):
    """Retorna variáveis de um arquivo .pickle
    
    Arguments:
        path {str}-- Caminho do arquivo 
    
    Returns:
        variables {list} -- Lista de variáveis
    """
    with open(path, 'rb') as f:
        # log(text = "Variables returned from path {}".format(path))
        return pickle.load(f)

# %%
# calculate probabilistic momentum between returns series of two assets (ex. market x bonds)
# probabilistic momentum can be defined as the probability or confidence that one asset (left) is going to outperform the other (right).
# lookback period: n days (not business days)
# p_currentDate = reference date - usually the current date 
def checkForProbMomentum(p_returns:pd.DataFrame, left_ticker: str, right_ticker: str, 
                         p_currentDate=pd.Timestamp, p_lookbackPeriod=66):
    
    v_startDate = p_currentDate - pd.DateOffset(days=p_lookbackPeriod)
    v_returns = p_returns.loc[ v_startDate:p_currentDate, [left_ticker,right_ticker] ]
        
    v_leftReturns = v_returns.iloc[:,0]
    v_rightReturns = v_returns.iloc[:,1]
        
    mom = ffn.calc_prob_mom(v_leftReturns, v_rightReturns)
     
    return mom

# %%
def getSmoothedReturns(p_returns: pd.DataFrame, p_smooth_fraction: float = 0.50):
     
    v_smoothed_returns = pd.DataFrame(index=p_returns.index)
    smoother = SpectralSmoother(smooth_fraction=p_smooth_fraction, pad_len=20)
    for i_name in p_returns.columns:
        i_returns = p_returns[i_name].dropna()
        # spectral smoother does not works if the number of data points is odd
        if ( len(i_returns.index) % 2 ) != 0:
            i_returns = i_returns[1:]              # remove the first row in case of odd number of points
        smoother.smooth(i_returns.values)
        i_returns_smooth_array = smoother.smooth_data[0][:]
        i_returns_smooth_series = pd.Series(i_returns_smooth_array, index=i_returns.index, name=i_returns.name)
        v_smoothed_returns = pd.concat([v_smoothed_returns, i_returns_smooth_series], axis=1)
        
    return v_smoothed_returns

# %%
def getBuyAndHoldStrategyReturns(p_returnsDf: pd.DataFrame, p_weightsDf: pd.DataFrame):
    
    indexes_list = list(p_returnsDf.index) + list(p_weightsDf.index)       # merge the indexes (timestamps) of the weights and returns Dataframes into a list
    indexes_set = set(indexes_list)                                        # remove the repeated indexes
    indexes_set = sorted(indexes_set)                                      # sort the indexes 
    v_weightsRdxDf = p_weightsDf.reindex(indexes_set, method='pad')  # reindexes weight DF with the following filling logic: propagate last valid observation forward to next valid 
    v_weightsRdxDf = v_weightsRdxDf.reindex(p_returnsDf.index)       #  reindexes weight DF according to the returns DF indexes
    # calculates pd.Series representing the daily total returns for the strategy
    calc = (p_returnsDf * v_weightsRdxDf)
    v_totalRetSeries = calc.sum(axis=1) + 1
    # get the daily cumulative return (pd.Series) for the strategy
    v_totalRetSeries.iloc[0] = 1                 # 1 + Ret_{port,t=0} = 1 - the total return for the timestamp t=0 is 1 
    v_cumRetSeries = v_totalRetSeries.cumprod()
    
    return v_totalRetSeries, v_cumRetSeries

# %%
def PyPortfolioOptimize(p_etfs: List[Stock], 
                        p_weeklyReturns:pd.DataFrame,
                        p_dateFrom: pd.Timestamp, p_dateTo: pd.Timestamp, 
                        p_minAssetLength: int = 66,
                        p_priceFiltering: bool = False, p_smoothingFactor: float = 0.75,
                        p_inSamplePeriod: int = 365, p_rollingPeriod: str = 'weekly', 
                        p_method: str = 'minVolatility',  p_maxBound: float = 1.0, 
                        verbose=True, p_solver: str = 'ECOS'):
    
    v_dateFromOutSample = p_dateFrom                                                     # ex: 2010-01-01
    v_dateToInSample = v_dateFromOutSample - pd.DateOffset(days=1)                       # ex: 2009-12-31  
    v_dateFromInSample = v_dateFromOutSample - pd.DateOffset(days=p_inSamplePeriod)     # ex: 2010-01-01 - 2 years = 2008-01-01  

    v_allEtfPricesDf = Stock.getAssetsAggregatedDf(p_etfs)                              # dataframe of etf's historical prices - etfs per columns
    v_allEtfReturnsDf = Stock.getAssetsReturnsDf(p_etfs, p_fillNa=False)                # dataFrame of returns for all universe of etfs - etfs per columns
    v_allEtfsIds = [a.id for a in p_etfs]
        
    v_weightsDf = pd.DataFrame(columns=v_allEtfsIds)                                # dataframe of portfolio weights - etfs per columns
    
    
    while (v_dateFromOutSample < p_dateTo):                                          
        
        #print(f'DEBUGGING for in-sample period: {v_dateFromInSample} -- {v_dateToInSample}')
             
        
        ### ------------------- Mandatory Steps of Asset Selection (pre-optimization steps)
        i_selectedEtfs = p_etfs   
        
        # remove assets that started after the last day of the in-sample period (v_dateToInSample); 
        # in addition, remove assets that started before the last day of the in-sample period but do not have enough days (p_minAssetLenght = 66 by default)
        # to be considered in the optimization process  
        i_removedEtfs = [a.id for a in i_selectedEtfs if len(a.dataFrame.loc[:v_dateToInSample]) < p_minAssetLength]   
        i_selectedEtfs = [a for a in i_selectedEtfs if a.id not in i_removedEtfs]
        #print(f'List of removed ETfs: {i_removedEtfs}')
        
        i_etfsIds = [s.id for s in i_selectedEtfs]
        v_etfPricesDf = v_allEtfPricesDf.loc[v_dateFromInSample:v_dateToInSample, i_etfsIds]
        v_etfReturnsDf = v_allEtfReturnsDf.loc[v_dateFromInSample:v_dateToInSample, i_etfsIds]
        
        v_pricesDf = v_etfPricesDf
        v_returnsDf = v_etfReturnsDf
            
        # removing RICs with NaN values 
        #v_pricesDf.dropna(axis='columns',inplace=True)
        
        #print(f'Number of RICs que restaram apos Procedimentos de Selecao e Filtragem (Remocao de Assets): {len(i_stocksIds)}')
        #v_pricesDf.info()
        
        # checking for columns (assets) having some NAN values 
        #bool_NAN_pricesDf = v_pricesDf.isnull().sum() > 0

        # printing the assets having NAN values  
        #v_NAN_assetList = [i for i in bool_NAN_pricesDf.index if bool_NAN_pricesDf[i]]
        #for i_asset in v_NAN_assetList:
           # print(f'asset: {i_asset}, total of non-NaN values: {v_pricesDf[i_asset].count()}')
            #print(f'asset: {i_asset}, number of NaN values: {v_pricesDf[i_asset].isna().sum()}')
        
        ### -------------- getting the portfolio (weight vector) for the corresponding insample period        
        
        if verbose == True:
            print(f'Starting calculating weights for period from: {v_dateFromInSample} to {v_dateToInSample}')
            print(f'SOLVER: {p_solver}')
            
        if p_priceFiltering:
            # estimating expected returns - returns a pd.Series that has the annualised mean (daily) return for each asset
            # drop NAN values if necessary 
            v_returnsDf_smoothed = getSmoothedReturns(p_returns=v_returnsDf, p_smooth_fraction=p_smoothingFactor)
            i_mu = expected_returns.mean_historical_return(v_returnsDf_smoothed, returns_data=True).dropna()
            # check if necessary to drop an asset from dataframe of historical prices
            dif = list(v_returnsDf_smoothed.columns.difference(i_mu.index))
            v_returnsDf_smoothed = v_returnsDf_smoothed.drop(dif, axis=1)
            i_S = risk_models.risk_matrix(v_returnsDf_smoothed, returns_data=True, method='ledoit_wolf_constant_variance')
        else:
            # estimating expected returns - returns a pd.Series that has the annualised mean (daily) return for each asset
            # drop NAN values if necessary 
            i_mu = expected_returns.mean_historical_return(v_pricesDf).dropna()      
            # check if necessary to drop an asset from dataframe of historical prices
            dif = list(v_pricesDf.columns.difference(i_mu.index))
            v_pricesDf = v_pricesDf.drop(dif, axis=1)
            # estimating covariance matrix - calculate the Ledoit-Wolf shrinkage estimate for a particular shrinkage target.
            i_S = risk_models.risk_matrix(v_pricesDf, method='ledoit_wolf_constant_variance')
            
        # Optimization Stage
        p_bounds = (0, 1)
        i_ef = EfficientFrontier(i_mu, i_S, weight_bounds=p_bounds, solver=p_solver, verbose=False)
        
        # -------------------------------------------------------------------------------------------------
        # calculate probabilistic momentum between market (SPY) x bonds (TAIL or TLT)
        tlt_index = i_ef.tickers.index("TLT.O")
        spy_index = i_ef.tickers.index("SPY")
        xlk_index = i_ef.tickers.index("XLK")
        #gld_index = i_ef.tickers.index("GLD")
        if 'TAIL.K' in v_returnsDf.columns:
            tail_index = i_ef.tickers.index("TAIL.K")
            mom_market = checkForProbMomentum(p_weeklyReturns, 'SPY', 'TAIL.K', v_dateToInSample, p_lookbackPeriod=60)
        else:
            mom_market = checkForProbMomentum(p_weeklyReturns, 'SPY', 'TLT.O', v_dateToInSample, p_lookbackPeriod=60)
        
        print(f'Market Momentum for {v_dateToInSample}: {mom_market}')
        if mom_market > 0.5:
            # add constraints
            i_ef.add_constraint(lambda w: w[:] <= p_maxBound)          
            i_ef.add_constraint(lambda w: w[tlt_index] == 0.00)
            #i_ef.add_constraint(lambda w: w[gld_index] == 0.00)
            if 'TAIL.K' in v_returnsDf.columns:
                i_ef.add_constraint(lambda w: w[tail_index] == 0.00)
            i_ef.add_constraint(lambda w: w[xlk_index] >= 0.50)
                    
        elif mom_market <= 0.5:
            # add constraints
            if 'TAIL.K' in v_returnsDf.columns:
                i_ef.add_constraint(lambda w: w[tlt_index] == 0.00)
                i_ef.add_constraint(lambda w: w[tail_index] >= 0.50)
                #i_ef.add_constraint(lambda w: w[gld_index] >= 0.20)
            elif 'TAIL.K' not in v_returnsDf.columns:
                i_ef.add_constraint(lambda w: w[tlt_index] >= 0.50)
                #i_ef.add_constraint(lambda w: w[gld_index] >= 0.20)
               
        if p_method == 'maxSharpe':
            i_weights = i_ef.max_sharpe(risk_free_rate=0)
        elif p_method == 'minVolatility':
            i_weights = i_ef.min_volatility()
        
        # post-processing weights
        v_cleaned_weights = i_ef.clean_weights()
        v_weightsSeries = pd.Series(v_cleaned_weights)
        
        print(v_weightsSeries [v_weightsSeries > 0])
        print(f'-------------------------------------------------------------\n\n\n')
        
        ### -------------- getting the portfolio (weight vector) for the corresponding insample period        
        
        v_portSymbols = [s for s in v_weightsSeries.index]
        
        # the reference date for the optimized portfolio is the start date of the Out of Sample period (v_dateFromOutSample)
        i_weightsIndex = v_dateFromOutSample
        v_weightsDf.loc[i_weightsIndex, :] = 0
        # assign the portfolio weights to the dataframe in the corresponding date
        for i_symbol in v_portSymbols:
            v_weightsDf.loc[i_weightsIndex, i_symbol] = v_weightsSeries.loc[i_symbol]
        
        
        ### ----------------- update to the next insample period
        if p_rollingPeriod == 'monthly':
            v_dateFromOutSample = v_dateFromOutSample + pd.DateOffset(months=1)
        elif p_rollingPeriod == 'weekly':
            v_dateFromOutSample = v_dateFromOutSample + pd.DateOffset(weeks=1)
        elif p_rollingPeriod == 'quarterly':
            v_dateFromOutSample = v_dateFromOutSample + pd.DateOffset(months=3)
        
        v_dateFromInSample = v_dateFromOutSample - pd.DateOffset(days=p_inSamplePeriod)
        v_dateToInSample = v_dateFromOutSample - pd.DateOffset(days=1)
        
    # end while
    
    if verbose == True:
        print(f'Optimization Finished!\n')

    # -----------------------
    # get the slice of the dataFrame of returns corresponding to the backtesting period (ex: v_dateFrom: 2010-01-01 - v_dateTo: 2020-11-23)
    
    v_etfReturnsDf = v_allEtfReturnsDf.loc[p_dateFrom:p_dateTo]
    
    v_totalRetSeries, v_cumRetSeries = getBuyAndHoldStrategyReturns(v_etfReturnsDf,v_weightsDf)
    
    return v_cumRetSeries

# %%
# get all ETFs (daily prices)

# get a list of Stocks (object) from Eikon US - folder containing all ETFs -> p_exchange='US_ETFs'
p_folderName='US_ETFs'    # name of folder where the database is kept 
v_etfsList = Stock.getStocksFromFiles(p_database='eikon', p_number=None, p_exchange=p_folderName, p_shuffle=False)

# select which ETFs from the ETF universe will participate of the strategy 
v_ricList = ['SPY', 'TLT.O', 'TAIL.K', 'XLK']
v_etfsSelList = [a for a in v_etfsList if a.id in v_ricList]

df_prices = Stock.getAssetsAggregatedDf(p_assetsList = v_etfsSelList, p_column = 'close')

df_prices
# Out:
#                GLD     XLK     SPY   TLT.O   TAIL.K
# 2002-01-02     NaN   24.60  115.53     NaN      NaN
# 2002-01-03     NaN   25.68  116.84     NaN      NaN
# 2002-01-04     NaN   25.84  117.62     NaN      NaN
# 2002-01-07     NaN   25.56  116.79     NaN      NaN
# 2002-01-08     NaN   25.75  116.52     NaN      NaN
# ...            ...     ...     ...     ...      ...
# 2021-09-24  163.30  156.71  443.91  146.91  18.4900
# 2021-09-27  163.64  155.19  442.64  146.37  18.4900
# 2021-09-28  162.05  150.59  433.72  144.09  18.6500
# 2021-09-29  161.32  150.40  434.45  144.34  18.6301
# 2021-09-30  164.22  149.32  429.14  144.32  18.7600
#
# [4972 rows x 5 columns]

# %%
# weekly returns - will be used only for computing the probabilistic momentum between market (SPY) and bonds (TLT or TAIL)
df_weeklyPrices = pd.read_csv('raw_weekly_prices.csv', parse_dates=True, index_col=0)
df_weeklyReturns = df_weeklyPrices.pct_change(axis=0)
df_weeklyReturns
# Out:
#                  XLK       SPY     TLT.O        TAIL.K       VIX
# 2002-01-04       NaN       NaN       NaN           NaN       NaN
# 2002-01-11  0.003416 -0.005857       NaN           NaN  0.031256
# 2002-01-18 -0.035899 -0.018779       NaN           NaN  0.032834
# 2002-01-25 -0.039151 -0.005444       NaN           NaN -0.043122
# 2002-02-01 -0.003689 -0.007196       NaN           NaN  0.012390
# ...              ...       ...       ...           ...       ...
# 2021-09-03  0.010492  0.009466 -0.000523 -2.664961e-03 -0.055446
# 2021-09-10 -0.005389 -0.007017 -0.005454  9.619496e-04  0.161918
# 2021-09-17 -0.008635 -0.008365  0.011906  3.256807e-03  0.017904
# 2021-09-24 -0.015005 -0.015526 -0.001440 -2.220446e-16  0.112009
# 2021-10-01 -0.020429 -0.008065 -0.033473 -8.433559e-03  0.021594
#
# [1031 rows x 5 columns]

# %%
# define the period of Backtesting 
v_dateFrom = pd.Timestamp('2015-01-05')          # should be a monday  
v_dateFromStr = v_dateFrom.strftime('%Y-%m-%d')
v_dateTo = pd.Timestamp('2021-09-30')
v_dateToStr = v_dateTo.strftime('%Y-%m-%d')

# ------------------------------------------------------
# strategy parameters 

# assets selection
v_priceFiltering = True                # flag that activates filtering of the historical prices dataFrame (via tsmoothie)
v_smoothingFactor = 0.75
v_minAssetLength = 66                  # minimum sample size (days) to be considered in the optimization process (in business days)

# portfolio optimization
v_solver = 'ECOS'
#v_solver = 'OSQP'
#v_solver = 'SCS'
v_inSamplePeriod = 365*2                # 2 years
#v_rollingPeriod = 'monthly'                  
#v_rollingPeriod = 'quarterly'
v_rollingPeriod = 'weekly'             
v_method = ['minVolatility','maxSharpe']
#v_method = ['minVolatility']
v_maxBound = 1.0                # max bound for stock weights in the portfolio

# strategy properties
v_strategyProperties = f'LongOnly_From_{v_dateFromStr}_To_{v_dateToStr}' \
+ f'_Model_MeanVariance' \
+ f'_{"PriceFiltering" if v_priceFiltering else "NoPriceFiltering"}' \
+ f'{v_smoothingFactor if v_priceFiltering else ""}' \
+ f'_InSmp{v_inSamplePeriod}d_Roll{v_rollingPeriod}' 

print(v_strategyProperties)

v_savingPath=f'Backtesting_Files/{v_strategyProperties}.pkl'

strategies_dict = {}
v_errors = []

for i_method in v_method:
        
    if i_method == 'minVolatility':
        i_metStr = 'minVol'
    elif i_method == 'maxSharpe':
        i_metStr = i_method
    keyName =  f'{i_metStr}'
        
    try:
        print(f'--------------------------------------------------------------\n')
        print(f'Starting Backtesting from {v_dateFrom} to {v_dateTo}\n')
        print(f'Strategy Name: {keyName} - Solver: {v_solver} \n')
        print(f'--------------------------------------------------------------\n')

        v_cumReturnsSeries = PyPortfolioOptimize(p_etfs=v_etfsSelList,
                                                 p_weeklyReturns = df_weeklyReturns,
                                                 p_dateFrom=v_dateFrom,
                                                 p_dateTo=v_dateTo,
                                                 p_priceFiltering=v_priceFiltering,
                                                 p_smoothingFactor=v_smoothingFactor, 
                                                 p_minAssetLength=v_minAssetLength,  
                                                 verbose=True,
                                                 p_inSamplePeriod=v_inSamplePeriod,
                                                 p_rollingPeriod=v_rollingPeriod,
                                                 p_method=i_method,
                                                 p_maxBound=v_maxBound,
                                                 p_solver = v_solver)
        # if optimization was successfull, then insert strategy's cumulative returns into dict 
        strategies_dict[keyName] = v_cumReturnsSeries
    
    except:
        traceback.print_exc()
        print(f'Error for {keyName}')
        v_errors.append(keyName)
            
              
print(f'Errors for portfolios: {v_errors}')

#save_to_pickle(v_savingPath, strategies_dict)
# Out:
# LongOnly_From_2015-01-05_To_2021-09-30_Model_MeanVariance_PriceFiltering0.75_InSmp730d_Rollweekly
# --------------------------------------------------------------
#
# Starting Backtesting from 2015-01-05 00:00:00 to 2021-09-30 00:00:00
#
# Strategy Name: minVol - Solver: ECOS
#
# --------------------------------------------------------------
#
# Starting calculating weights for period from: 2013-01-05 00:00:00 to 2015-01-04 00:00:00
# SOLVER: ECOS
# Market Momentum for 2015-01-04 00:00:00: 0.4752359536288395
# GLD      0.20000
# XLK      0.12756
# SPY      0.17244
# TLT.O    0.50000
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2013-01-12 00:00:00 to 2015-01-11 00:00:00
# SOLVER: ECOS
# Market Momentum for 2015-01-11 00:00:00: 0.3649818807264694
# GLD      0.20000
# XLK      0.12559
# SPY      0.17441
# TLT.O    0.50000
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2013-01-19 00:00:00 to 2015-01-18 00:00:00
# SOLVER: ECOS
# Market Momentum for 2015-01-18 00:00:00: 0.31055498013393845
# GLD      0.20000
# XLK      0.12701
# SPY      0.17299
# TLT.O    0.50000
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2013-01-26 00:00:00 to 2015-01-25 00:00:00
# SOLVER: ECOS
# Market Momentum for 2015-01-25 00:00:00: 0.3165263337021885
# GLD      0.20000
# XLK      0.13479
# SPY      0.16521
# TLT.O    0.50000
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2013-02-02 00:00:00 to 2015-02-01 00:00:00
# SOLVER: ECOS
# Market Momentum for 2015-02-01 00:00:00: 0.29430065125958405
# GLD      0.2000
# XLK      0.1197
# SPY      0.1803
# TLT.O    0.5000
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2013-02-09 00:00:00 to 2015-02-08 00:00:00
# SOLVER: ECOS
# Market Momentum for 2015-02-08 00:00:00: 0.34064028066702784
# GLD      0.20000
# XLK      0.11912
# SPY      0.18088
# TLT.O    0.50000
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2013-02-16 00:00:00 to 2015-02-15 00:00:00
# SOLVER: ECOS
# Market Momentum for 2015-02-15 00:00:00: 0.4645259272640067
# GLD      0.20000
# XLK      0.12093
# SPY      0.17907
# TLT.O    0.50000
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2013-02-23 00:00:00 to 2015-02-22 00:00:00
# SOLVER: ECOS
# Market Momentum for 2015-02-22 00:00:00: 0.5394275088090195
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2013-03-02 00:00:00 to 2015-03-01 00:00:00
# SOLVER: ECOS
# Market Momentum for 2015-03-01 00:00:00: 0.47253855984183973
# GLD      0.20000
# XLK      0.12833
# SPY      0.17167
# TLT.O    0.50000
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2013-03-09 00:00:00 to 2015-03-08 00:00:00
# SOLVER: ECOS
# Market Momentum for 2015-03-08 00:00:00: 0.5199109103077156
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2013-03-16 00:00:00 to 2015-03-15 00:00:00
# SOLVER: ECOS
# Market Momentum for 2015-03-15 00:00:00: 0.5708331452389166
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2013-03-23 00:00:00 to 2015-03-22 00:00:00
# SOLVER: ECOS
# Market Momentum for 2015-03-22 00:00:00: 0.5907759564538593
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2013-03-30 00:00:00 to 2015-03-29 00:00:00
# SOLVER: ECOS
# Market Momentum for 2015-03-29 00:00:00: 0.551303625652388
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2013-04-06 00:00:00 to 2015-04-05 00:00:00
# SOLVER: ECOS
# Market Momentum for 2015-04-05 00:00:00: 0.5929429799411248
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2013-04-13 00:00:00 to 2015-04-12 00:00:00
# SOLVER: ECOS
# Market Momentum for 2015-04-12 00:00:00: 0.5771551436955759
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2013-04-20 00:00:00 to 2015-04-19 00:00:00
# SOLVER: ECOS
# Market Momentum for 2015-04-19 00:00:00: 0.5046675290225378
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2013-04-27 00:00:00 to 2015-04-26 00:00:00
# SOLVER: ECOS
# Market Momentum for 2015-04-26 00:00:00: 0.4503840745454689
# GLD      0.20000
# XLK      0.06706
# SPY      0.23294
# TLT.O    0.50000
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2013-05-04 00:00:00 to 2015-05-03 00:00:00
# SOLVER: ECOS
# Market Momentum for 2015-05-03 00:00:00: 0.5414564616324506
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2013-05-11 00:00:00 to 2015-05-10 00:00:00
# SOLVER: ECOS
# Market Momentum for 2015-05-10 00:00:00: 0.5614420247340794
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2013-05-18 00:00:00 to 2015-05-17 00:00:00
# SOLVER: ECOS
# Market Momentum for 2015-05-17 00:00:00: 0.6814444812741562
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2013-05-25 00:00:00 to 2015-05-24 00:00:00
# SOLVER: ECOS
# Market Momentum for 2015-05-24 00:00:00: 0.7653230326190452
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2013-06-01 00:00:00 to 2015-05-31 00:00:00
# SOLVER: ECOS
# Market Momentum for 2015-05-31 00:00:00: 0.6953070047474563
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2013-06-08 00:00:00 to 2015-06-07 00:00:00
# SOLVER: ECOS
# Market Momentum for 2015-06-07 00:00:00: 0.7422509973154492
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2013-06-15 00:00:00 to 2015-06-14 00:00:00
# SOLVER: ECOS
# Market Momentum for 2015-06-14 00:00:00: 0.7365412921760273
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2013-06-22 00:00:00 to 2015-06-21 00:00:00
# SOLVER: ECOS
# Market Momentum for 2015-06-21 00:00:00: 0.7078682356666617
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2013-06-29 00:00:00 to 2015-06-28 00:00:00
# SOLVER: ECOS
# Market Momentum for 2015-06-28 00:00:00: 0.7104696919648537
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2013-07-06 00:00:00 to 2015-07-05 00:00:00
# SOLVER: ECOS
# Market Momentum for 2015-07-05 00:00:00: 0.607911946727685
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2013-07-13 00:00:00 to 2015-07-12 00:00:00
# SOLVER: ECOS
# Market Momentum for 2015-07-12 00:00:00: 0.5278574084937281
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2013-07-20 00:00:00 to 2015-07-19 00:00:00
# SOLVER: ECOS
# Market Momentum for 2015-07-19 00:00:00: 0.5409934673312115
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2013-07-27 00:00:00 to 2015-07-26 00:00:00
# SOLVER: ECOS
# Market Momentum for 2015-07-26 00:00:00: 0.4739568424922944
# GLD      0.20000
# XLK      0.01856
# SPY      0.28144
# TLT.O    0.50000
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2013-08-03 00:00:00 to 2015-08-02 00:00:00
# SOLVER: ECOS
# Market Momentum for 2015-08-02 00:00:00: 0.4947465294863802
# GLD      0.20000
# XLK      0.02525
# SPY      0.27475
# TLT.O    0.50000
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2013-08-10 00:00:00 to 2015-08-09 00:00:00
# SOLVER: ECOS
# Market Momentum for 2015-08-09 00:00:00: 0.413070222870794
# GLD      0.2000
# XLK      0.0162
# SPY      0.2838
# TLT.O    0.5000
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2013-08-17 00:00:00 to 2015-08-16 00:00:00
# SOLVER: ECOS
# Market Momentum for 2015-08-16 00:00:00: 0.374152774743995
# GLD      0.20000
# XLK      0.01499
# SPY      0.28501
# TLT.O    0.50000
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2013-08-24 00:00:00 to 2015-08-23 00:00:00
# SOLVER: ECOS
# Market Momentum for 2015-08-23 00:00:00: 0.3464650483213395
# GLD      0.20000
# XLK      0.00892
# SPY      0.29108
# TLT.O    0.50000
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2013-08-31 00:00:00 to 2015-08-30 00:00:00
# SOLVER: ECOS
# Market Momentum for 2015-08-30 00:00:00: 0.24224688162828295
# GLD      0.20000
# XLK      0.03474
# SPY      0.26526
# TLT.O    0.50000
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2013-09-07 00:00:00 to 2015-09-06 00:00:00
# SOLVER: ECOS
# Market Momentum for 2015-09-06 00:00:00: 0.32614884784872356
# GLD      0.20000
# XLK      0.03412
# SPY      0.26588
# TLT.O    0.50000
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2013-09-14 00:00:00 to 2015-09-13 00:00:00
# SOLVER: ECOS
# Market Momentum for 2015-09-13 00:00:00: 0.3782614858930575
# GLD      0.20000
# XLK      0.03604
# SPY      0.26396
# TLT.O    0.50000
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2013-09-21 00:00:00 to 2015-09-20 00:00:00
# SOLVER: ECOS
# Market Momentum for 2015-09-20 00:00:00: 0.3270525985330493
# GLD      0.20000
# XLK      0.04656
# SPY      0.25344
# TLT.O    0.50000
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2013-09-28 00:00:00 to 2015-09-27 00:00:00
# SOLVER: ECOS
# Market Momentum for 2015-09-27 00:00:00: 0.3214476786622778
# GLD      0.20000
# XLK      0.04571
# SPY      0.25429
# TLT.O    0.50000
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2013-10-05 00:00:00 to 2015-10-04 00:00:00
# SOLVER: ECOS
# Market Momentum for 2015-10-04 00:00:00: 0.3072573072656698
# GLD      0.20000
# XLK      0.05312
# SPY      0.24688
# TLT.O    0.50000
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2013-10-12 00:00:00 to 2015-10-11 00:00:00
# SOLVER: ECOS
# Market Momentum for 2015-10-11 00:00:00: 0.44523829130580245
# GLD      0.20000
# XLK      0.05097
# SPY      0.24903
# TLT.O    0.50000
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2013-10-19 00:00:00 to 2015-10-18 00:00:00
# SOLVER: ECOS
# Market Momentum for 2015-10-18 00:00:00: 0.4532991662137849
# GLD      0.20000
# XLK      0.03232
# SPY      0.26768
# TLT.O    0.50000
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2013-10-26 00:00:00 to 2015-10-25 00:00:00
# SOLVER: ECOS
# Market Momentum for 2015-10-25 00:00:00: 0.5070572325928561
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2013-11-02 00:00:00 to 2015-11-01 00:00:00
# SOLVER: ECOS
# Market Momentum for 2015-11-01 00:00:00: 0.610331921970177
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2013-11-09 00:00:00 to 2015-11-08 00:00:00
# SOLVER: ECOS
# Market Momentum for 2015-11-08 00:00:00: 0.6295351238672091
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2013-11-16 00:00:00 to 2015-11-15 00:00:00
# SOLVER: ECOS
# Market Momentum for 2015-11-15 00:00:00: 0.6044390408418141
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2013-11-23 00:00:00 to 2015-11-22 00:00:00
# SOLVER: ECOS
# Market Momentum for 2015-11-22 00:00:00: 0.5750276852939415
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2013-11-30 00:00:00 to 2015-11-29 00:00:00
# SOLVER: ECOS
# Market Momentum for 2015-11-29 00:00:00: 0.6351719575089673
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2013-12-07 00:00:00 to 2015-12-06 00:00:00
# SOLVER: ECOS
# Market Momentum for 2015-12-06 00:00:00: 0.7100597879059978
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2013-12-14 00:00:00 to 2015-12-13 00:00:00
# SOLVER: ECOS
# Market Momentum for 2015-12-13 00:00:00: 0.5896592667424082
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2013-12-21 00:00:00 to 2015-12-20 00:00:00
# SOLVER: ECOS
# Market Momentum for 2015-12-20 00:00:00: 0.5714768427756955
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2013-12-28 00:00:00 to 2015-12-27 00:00:00
# SOLVER: ECOS
# Market Momentum for 2015-12-27 00:00:00: 0.5311005561323324
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2014-01-04 00:00:00 to 2016-01-03 00:00:00
# SOLVER: ECOS
# Market Momentum for 2016-01-03 00:00:00: 0.5285123248199481
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2014-01-11 00:00:00 to 2016-01-10 00:00:00
# SOLVER: ECOS
# Market Momentum for 2016-01-10 00:00:00: 0.3388868788066324
# GLD      0.20000
# XLK      0.02415
# SPY      0.27585
# TLT.O    0.50000
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2014-01-18 00:00:00 to 2016-01-17 00:00:00
# SOLVER: ECOS
# Market Momentum for 2016-01-17 00:00:00: 0.2911334725452291
# GLD      0.20000
# XLK      0.02757
# SPY      0.27243
# TLT.O    0.50000
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2014-01-25 00:00:00 to 2016-01-24 00:00:00
# SOLVER: ECOS
# Market Momentum for 2016-01-24 00:00:00: 0.25743258797067514
# GLD      0.20000
# XLK      0.02774
# SPY      0.27226
# TLT.O    0.50000
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2014-02-01 00:00:00 to 2016-01-31 00:00:00
# SOLVER: ECOS
# Market Momentum for 2016-01-31 00:00:00: 0.26793132083017046
# GLD      0.20000
# XLK      0.02135
# SPY      0.27865
# TLT.O    0.50000
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2014-02-08 00:00:00 to 2016-02-07 00:00:00
# SOLVER: ECOS
# Market Momentum for 2016-02-07 00:00:00: 0.26663042134151027
# GLD      0.20000
# XLK      0.02217
# SPY      0.27783
# TLT.O    0.50000
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2014-02-15 00:00:00 to 2016-02-14 00:00:00
# SOLVER: ECOS
# Market Momentum for 2016-02-14 00:00:00: 0.2489253921920721
# GLD      0.20000
# XLK      0.00909
# SPY      0.29091
# TLT.O    0.50000
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2014-02-22 00:00:00 to 2016-02-21 00:00:00
# SOLVER: ECOS
# Market Momentum for 2016-02-21 00:00:00: 0.3569387989871283
# GLD      0.2000
# XLK      0.0062
# SPY      0.2938
# TLT.O    0.5000
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2014-03-01 00:00:00 to 2016-02-28 00:00:00
# SOLVER: ECOS
# Market Momentum for 2016-02-28 00:00:00: 0.36603082424732303
# GLD      0.20000
# XLK      0.00111
# SPY      0.29889
# TLT.O    0.50000
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2014-03-08 00:00:00 to 2016-03-06 00:00:00
# SOLVER: ECOS
# Market Momentum for 2016-03-06 00:00:00: 0.38936163071391
# GLD      0.20000
# XLK      0.00973
# SPY      0.29027
# TLT.O    0.50000
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2014-03-15 00:00:00 to 2016-03-13 00:00:00
# SOLVER: ECOS
# Market Momentum for 2016-03-13 00:00:00: 0.4569688462947526
# GLD      0.20000
# XLK      0.01138
# SPY      0.28862
# TLT.O    0.50000
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2014-03-22 00:00:00 to 2016-03-20 00:00:00
# SOLVER: ECOS
# Market Momentum for 2016-03-20 00:00:00: 0.538852907153839
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2014-03-29 00:00:00 to 2016-03-27 00:00:00
# SOLVER: ECOS
# Market Momentum for 2016-03-27 00:00:00: 0.5814419590177261
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2014-04-05 00:00:00 to 2016-04-03 00:00:00
# SOLVER: ECOS
# Market Momentum for 2016-04-03 00:00:00: 0.5655246560868642
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2014-04-12 00:00:00 to 2016-04-10 00:00:00
# SOLVER: ECOS
# Market Momentum for 2016-04-10 00:00:00: 0.5594479014087944
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2014-04-19 00:00:00 to 2016-04-17 00:00:00
# SOLVER: ECOS
# Market Momentum for 2016-04-17 00:00:00: 0.7381268293053396
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2014-04-26 00:00:00 to 2016-04-24 00:00:00
# SOLVER: ECOS
# Market Momentum for 2016-04-24 00:00:00: 0.7444043937678505
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2014-05-03 00:00:00 to 2016-05-01 00:00:00
# SOLVER: ECOS
# Market Momentum for 2016-05-01 00:00:00: 0.7369256713690289
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2014-05-10 00:00:00 to 2016-05-08 00:00:00
# SOLVER: ECOS
# Market Momentum for 2016-05-08 00:00:00: 0.5970215916225341
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2014-05-17 00:00:00 to 2016-05-15 00:00:00
# SOLVER: ECOS
# Market Momentum for 2016-05-15 00:00:00: 0.5311407973657429
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2014-05-24 00:00:00 to 2016-05-22 00:00:00
# SOLVER: ECOS
# Market Momentum for 2016-05-22 00:00:00: 0.4771556140618846
# GLD      0.2
# SPY      0.3
# TLT.O    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2014-05-31 00:00:00 to 2016-05-29 00:00:00
# SOLVER: ECOS
# Market Momentum for 2016-05-29 00:00:00: 0.5365716336534068
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2014-06-07 00:00:00 to 2016-06-05 00:00:00
# SOLVER: ECOS
# Market Momentum for 2016-06-05 00:00:00: 0.5470721218971386
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2014-06-14 00:00:00 to 2016-06-12 00:00:00
# SOLVER: ECOS
# Market Momentum for 2016-06-12 00:00:00: 0.5543110500954731
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2014-06-21 00:00:00 to 2016-06-19 00:00:00
# SOLVER: ECOS
# Market Momentum for 2016-06-19 00:00:00: 0.4372767873524568
# GLD      0.20000
# XLK      0.00158
# SPY      0.29842
# TLT.O    0.50000
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2014-06-28 00:00:00 to 2016-06-26 00:00:00
# SOLVER: ECOS
# Market Momentum for 2016-06-26 00:00:00: 0.3978146566997437
# GLD      0.20000
# XLK      0.00837
# SPY      0.29163
# TLT.O    0.50000
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2014-07-05 00:00:00 to 2016-07-03 00:00:00
# SOLVER: ECOS
# Market Momentum for 2016-07-03 00:00:00: 0.32397313064511046
# GLD      0.20000
# XLK      0.01043
# SPY      0.28957
# TLT.O    0.50000
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2014-07-12 00:00:00 to 2016-07-10 00:00:00
# SOLVER: ECOS
# Market Momentum for 2016-07-10 00:00:00: 0.35211110044474153
# GLD      0.2000
# XLK      0.0101
# SPY      0.2899
# TLT.O    0.5000
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2014-07-19 00:00:00 to 2016-07-17 00:00:00
# SOLVER: ECOS
# Market Momentum for 2016-07-17 00:00:00: 0.457690955926162
# GLD      0.20000
# XLK      0.01383
# SPY      0.28617
# TLT.O    0.50000
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2014-07-26 00:00:00 to 2016-07-24 00:00:00
# SOLVER: ECOS
# Market Momentum for 2016-07-24 00:00:00: 0.48863247207548244
# GLD      0.20000
# XLK      0.02186
# SPY      0.27814
# TLT.O    0.50000
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2014-08-02 00:00:00 to 2016-07-31 00:00:00
# SOLVER: ECOS
# Market Momentum for 2016-07-31 00:00:00: 0.4422530651942941
# GLD      0.20000
# XLK      0.01141
# SPY      0.28859
# TLT.O    0.50000
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2014-08-09 00:00:00 to 2016-08-07 00:00:00
# SOLVER: ECOS
# Market Momentum for 2016-08-07 00:00:00: 0.4580084242391626
# GLD      0.20000
# XLK      0.00948
# SPY      0.29052
# TLT.O    0.50000
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2014-08-16 00:00:00 to 2016-08-14 00:00:00
# SOLVER: ECOS
# Market Momentum for 2016-08-14 00:00:00: 0.4782891086437747
# GLD      0.20000
# XLK      0.00659
# SPY      0.29341
# TLT.O    0.50000
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2014-08-23 00:00:00 to 2016-08-21 00:00:00
# SOLVER: ECOS
# Market Momentum for 2016-08-21 00:00:00: 0.5458181775703849
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2014-08-30 00:00:00 to 2016-08-28 00:00:00
# SOLVER: ECOS
# Market Momentum for 2016-08-28 00:00:00: 0.5132935864112748
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2014-09-06 00:00:00 to 2016-09-04 00:00:00
# SOLVER: ECOS
# Market Momentum for 2016-09-04 00:00:00: 0.6461553335662749
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2014-09-13 00:00:00 to 2016-09-11 00:00:00
# SOLVER: ECOS
# Market Momentum for 2016-09-11 00:00:00: 0.6825646112490135
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2014-09-20 00:00:00 to 2016-09-18 00:00:00
# SOLVER: ECOS
# Market Momentum for 2016-09-18 00:00:00: 0.6722197070530722
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2014-09-27 00:00:00 to 2016-09-25 00:00:00
# SOLVER: ECOS
# Market Momentum for 2016-09-25 00:00:00: 0.574694240816302
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2014-10-04 00:00:00 to 2016-10-02 00:00:00
# SOLVER: ECOS
# Market Momentum for 2016-10-02 00:00:00: 0.5316772788361339
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2014-10-11 00:00:00 to 2016-10-09 00:00:00
# SOLVER: ECOS
# Market Momentum for 2016-10-09 00:00:00: 0.5796488051725803
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2014-10-18 00:00:00 to 2016-10-16 00:00:00
# SOLVER: ECOS
# Market Momentum for 2016-10-16 00:00:00: 0.5985856343104126
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2014-10-25 00:00:00 to 2016-10-23 00:00:00
# SOLVER: ECOS
# Market Momentum for 2016-10-23 00:00:00: 0.5718981069302341
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2014-11-01 00:00:00 to 2016-10-30 00:00:00
# SOLVER: ECOS
# Market Momentum for 2016-10-30 00:00:00: 0.6248662548121231
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2014-11-08 00:00:00 to 2016-11-06 00:00:00
# SOLVER: ECOS
# Market Momentum for 2016-11-06 00:00:00: 0.5828588236716858
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2014-11-15 00:00:00 to 2016-11-13 00:00:00
# SOLVER: ECOS
# Market Momentum for 2016-11-13 00:00:00: 0.6388449750175229
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2014-11-22 00:00:00 to 2016-11-20 00:00:00
# SOLVER: ECOS
# Market Momentum for 2016-11-20 00:00:00: 0.6738305274104954
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2014-11-29 00:00:00 to 2016-11-27 00:00:00
# SOLVER: ECOS
# Market Momentum for 2016-11-27 00:00:00: 0.7115061264165092
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2014-12-06 00:00:00 to 2016-12-04 00:00:00
# SOLVER: ECOS
# Market Momentum for 2016-12-04 00:00:00: 0.75151086197219
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2014-12-13 00:00:00 to 2016-12-11 00:00:00
# SOLVER: ECOS
# Market Momentum for 2016-12-11 00:00:00: 0.7552622021009026
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2014-12-20 00:00:00 to 2016-12-18 00:00:00
# SOLVER: ECOS
# Market Momentum for 2016-12-18 00:00:00: 0.7784921592261178
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2014-12-27 00:00:00 to 2016-12-25 00:00:00
# SOLVER: ECOS
# Market Momentum for 2016-12-25 00:00:00: 0.7650684929250653
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2015-01-03 00:00:00 to 2017-01-01 00:00:00
# SOLVER: ECOS
# Market Momentum for 2017-01-01 00:00:00: 0.7304071197614252
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2015-01-10 00:00:00 to 2017-01-08 00:00:00
# SOLVER: ECOS
# Market Momentum for 2017-01-08 00:00:00: 0.7356028759322448
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2015-01-17 00:00:00 to 2017-01-15 00:00:00
# SOLVER: ECOS
# Market Momentum for 2017-01-15 00:00:00: 0.6685557536088924
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2015-01-24 00:00:00 to 2017-01-22 00:00:00
# SOLVER: ECOS
# Market Momentum for 2017-01-22 00:00:00: 0.6197441161776773
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2015-01-31 00:00:00 to 2017-01-29 00:00:00
# SOLVER: ECOS
# Market Momentum for 2017-01-29 00:00:00: 0.6184908979683454
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2015-02-07 00:00:00 to 2017-02-05 00:00:00
# SOLVER: ECOS
# Market Momentum for 2017-02-05 00:00:00: 0.6228996236928422
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2015-02-14 00:00:00 to 2017-02-12 00:00:00
# SOLVER: ECOS
# Market Momentum for 2017-02-12 00:00:00: 0.5412217329247965
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2015-02-21 00:00:00 to 2017-02-19 00:00:00
# SOLVER: ECOS
# Market Momentum for 2017-02-19 00:00:00: 0.5469012854514282
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2015-02-28 00:00:00 to 2017-02-26 00:00:00
# SOLVER: ECOS
# Market Momentum for 2017-02-26 00:00:00: 0.5783950704021315
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2015-03-07 00:00:00 to 2017-03-05 00:00:00
# SOLVER: ECOS
# Market Momentum for 2017-03-05 00:00:00: 0.6491019383718901
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2015-03-14 00:00:00 to 2017-03-12 00:00:00
# SOLVER: ECOS
# Market Momentum for 2017-03-12 00:00:00: 0.7414317515920823
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2015-03-21 00:00:00 to 2017-03-19 00:00:00
# SOLVER: ECOS
# Market Momentum for 2017-03-19 00:00:00: 0.8021622650886018
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2015-03-28 00:00:00 to 2017-03-26 00:00:00
# SOLVER: ECOS
# Market Momentum for 2017-03-26 00:00:00: 0.595950388325517
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2015-04-04 00:00:00 to 2017-04-02 00:00:00
# SOLVER: ECOS
# Market Momentum for 2017-04-02 00:00:00: 0.5515790912921177
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2015-04-11 00:00:00 to 2017-04-09 00:00:00
# SOLVER: ECOS
# Market Momentum for 2017-04-09 00:00:00: 0.5381048466743275
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2015-04-18 00:00:00 to 2017-04-16 00:00:00
# SOLVER: ECOS
# Market Momentum for 2017-04-16 00:00:00: 0.5104648182719096
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2015-04-25 00:00:00 to 2017-04-23 00:00:00
# SOLVER: ECOS
# Market Momentum for 2017-04-23 00:00:00: 0.4085195660701382
# GLD      0.2
# SPY      0.3
# TLT.O    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2015-05-02 00:00:00 to 2017-04-30 00:00:00
# SOLVER: ECOS
# Market Momentum for 2017-04-30 00:00:00: 0.4887178685704984
# GLD      0.2
# SPY      0.3
# TLT.O    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2015-05-09 00:00:00 to 2017-05-07 00:00:00
# SOLVER: ECOS
# Market Momentum for 2017-05-07 00:00:00: 0.4840718479070473
# GLD      0.2
# SPY      0.3
# TLT.O    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2015-05-16 00:00:00 to 2017-05-14 00:00:00
# SOLVER: ECOS
# Market Momentum for 2017-05-14 00:00:00: 0.464315472596947
# GLD      0.2
# SPY      0.3
# TLT.O    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2015-05-23 00:00:00 to 2017-05-21 00:00:00
# SOLVER: ECOS
# Market Momentum for 2017-05-21 00:00:00: 0.4117343238681528
# GLD      0.2
# SPY      0.3
# TLT.O    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2015-05-30 00:00:00 to 2017-05-28 00:00:00
# SOLVER: ECOS
# Market Momentum for 2017-05-28 00:00:00: 0.5052733418899099
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2015-06-06 00:00:00 to 2017-06-04 00:00:00
# SOLVER: ECOS
# Market Momentum for 2017-06-04 00:00:00: 0.5014338415613748
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2015-06-13 00:00:00 to 2017-06-11 00:00:00
# SOLVER: ECOS
# Market Momentum for 2017-06-11 00:00:00: 0.5143501482679029
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2015-06-20 00:00:00 to 2017-06-18 00:00:00
# SOLVER: ECOS
# Market Momentum for 2017-06-18 00:00:00: 0.5487712593396848
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2015-06-27 00:00:00 to 2017-06-25 00:00:00
# SOLVER: ECOS
# Market Momentum for 2017-06-25 00:00:00: 0.5262074780939272
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2015-07-04 00:00:00 to 2017-07-02 00:00:00
# SOLVER: ECOS
# Market Momentum for 2017-07-02 00:00:00: 0.42947795556147056
# GLD      0.2
# SPY      0.3
# TLT.O    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2015-07-11 00:00:00 to 2017-07-09 00:00:00
# SOLVER: ECOS
# Market Momentum for 2017-07-09 00:00:00: 0.474700560305795
# GLD      0.2
# SPY      0.3
# TLT.O    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2015-07-18 00:00:00 to 2017-07-16 00:00:00
# SOLVER: ECOS
# Market Momentum for 2017-07-16 00:00:00: 0.6518714625391133
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2015-07-25 00:00:00 to 2017-07-23 00:00:00
# SOLVER: ECOS
# Market Momentum for 2017-07-23 00:00:00: 0.895572969968986
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2015-08-01 00:00:00 to 2017-07-30 00:00:00
# SOLVER: ECOS
# Market Momentum for 2017-07-30 00:00:00: 0.9083938883934044
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2015-08-08 00:00:00 to 2017-08-06 00:00:00
# SOLVER: ECOS
# Market Momentum for 2017-08-06 00:00:00: 0.8193064519366776
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2015-08-15 00:00:00 to 2017-08-13 00:00:00
# SOLVER: ECOS
# Market Momentum for 2017-08-13 00:00:00: 0.6491504223112786
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2015-08-22 00:00:00 to 2017-08-20 00:00:00
# SOLVER: ECOS
# Market Momentum for 2017-08-20 00:00:00: 0.6116658571979825
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2015-08-29 00:00:00 to 2017-08-27 00:00:00
# SOLVER: ECOS
# Market Momentum for 2017-08-27 00:00:00: 0.5631470742221939
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2015-09-05 00:00:00 to 2017-09-03 00:00:00
# SOLVER: ECOS
# Market Momentum for 2017-09-03 00:00:00: 0.584996232374815
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2015-09-12 00:00:00 to 2017-09-10 00:00:00
# SOLVER: ECOS
# Market Momentum for 2017-09-10 00:00:00: 0.5349273461577757
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2015-09-19 00:00:00 to 2017-09-17 00:00:00
# SOLVER: ECOS
# Market Momentum for 2017-09-17 00:00:00: 0.57284018844513
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2015-09-26 00:00:00 to 2017-09-24 00:00:00
# SOLVER: ECOS
# Market Momentum for 2017-09-24 00:00:00: 0.5682421967130931
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2015-10-03 00:00:00 to 2017-10-01 00:00:00
# SOLVER: ECOS
# Market Momentum for 2017-10-01 00:00:00: 0.5572992951556138
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2015-10-10 00:00:00 to 2017-10-08 00:00:00
# SOLVER: ECOS
# Market Momentum for 2017-10-08 00:00:00: 0.6335051649424726
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2015-10-17 00:00:00 to 2017-10-15 00:00:00
# SOLVER: ECOS
# Market Momentum for 2017-10-15 00:00:00: 0.7144836954894109
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2015-10-24 00:00:00 to 2017-10-22 00:00:00
# SOLVER: ECOS
# Market Momentum for 2017-10-22 00:00:00: 0.7677595358378022
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2015-10-31 00:00:00 to 2017-10-29 00:00:00
# SOLVER: ECOS
# Market Momentum for 2017-10-29 00:00:00: 0.8500643982676825
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2015-11-07 00:00:00 to 2017-11-05 00:00:00
# SOLVER: ECOS
# Market Momentum for 2017-11-05 00:00:00: 0.8343609188619654
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2015-11-14 00:00:00 to 2017-11-12 00:00:00
# SOLVER: ECOS
# Market Momentum for 2017-11-12 00:00:00: 0.8592487187805127
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2015-11-21 00:00:00 to 2017-11-19 00:00:00
# SOLVER: ECOS
# Market Momentum for 2017-11-19 00:00:00: 0.8043267315350695
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2015-11-28 00:00:00 to 2017-11-26 00:00:00
# SOLVER: ECOS
# Market Momentum for 2017-11-26 00:00:00: 0.8068310882986505
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2015-12-05 00:00:00 to 2017-12-03 00:00:00
# SOLVER: ECOS
# Market Momentum for 2017-12-03 00:00:00: 0.8257264052914149
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2015-12-12 00:00:00 to 2017-12-10 00:00:00
# SOLVER: ECOS
# Market Momentum for 2017-12-10 00:00:00: 0.8359066494061651
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2015-12-19 00:00:00 to 2017-12-17 00:00:00
# SOLVER: ECOS
# Market Momentum for 2017-12-17 00:00:00: 0.8519491770157612
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2015-12-26 00:00:00 to 2017-12-24 00:00:00
# SOLVER: ECOS
# Market Momentum for 2017-12-24 00:00:00: 0.8643342122997012
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2016-01-02 00:00:00 to 2017-12-31 00:00:00
# SOLVER: ECOS
# Market Momentum for 2017-12-31 00:00:00: 0.8148535170886191
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2016-01-09 00:00:00 to 2018-01-07 00:00:00
# SOLVER: ECOS
# Market Momentum for 2018-01-07 00:00:00: 0.8325424861407931
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2016-01-16 00:00:00 to 2018-01-14 00:00:00
# SOLVER: ECOS
# Market Momentum for 2018-01-14 00:00:00: 0.8664749827333914
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2016-01-23 00:00:00 to 2018-01-21 00:00:00
# SOLVER: ECOS
# Market Momentum for 2018-01-21 00:00:00: 0.9377936992223311
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2016-01-30 00:00:00 to 2018-01-28 00:00:00
# SOLVER: ECOS
# Market Momentum for 2018-01-28 00:00:00: 0.9426841176151547
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2016-02-06 00:00:00 to 2018-02-04 00:00:00
# SOLVER: ECOS
# Market Momentum for 2018-02-04 00:00:00: 0.8555384362809422
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2016-02-13 00:00:00 to 2018-02-11 00:00:00
# SOLVER: ECOS
# Market Momentum for 2018-02-11 00:00:00: 0.5015867227920081
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2016-02-20 00:00:00 to 2018-02-18 00:00:00
# SOLVER: ECOS
# Market Momentum for 2018-02-18 00:00:00: 0.5387391462967532
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2016-02-27 00:00:00 to 2018-02-25 00:00:00
# SOLVER: ECOS
# Market Momentum for 2018-02-25 00:00:00: 0.540618202947387
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2016-03-05 00:00:00 to 2018-03-04 00:00:00
# SOLVER: ECOS
# Market Momentum for 2018-03-04 00:00:00: 0.5447988271837374
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2016-03-12 00:00:00 to 2018-03-11 00:00:00
# SOLVER: ECOS
# Market Momentum for 2018-03-11 00:00:00: 0.5316597680796682
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2016-03-19 00:00:00 to 2018-03-18 00:00:00
# SOLVER: ECOS
# Market Momentum for 2018-03-18 00:00:00: 0.5145192395502969
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2016-03-26 00:00:00 to 2018-03-25 00:00:00
# SOLVER: ECOS
# Market Momentum for 2018-03-25 00:00:00: 0.45408198093670726
# GLD       0.20000
# XLK       0.02379
# SPY       0.27621
# TAIL.K    0.50000
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2016-04-02 00:00:00 to 2018-04-01 00:00:00
# SOLVER: ECOS
# Market Momentum for 2018-04-01 00:00:00: 0.407689903553687
# GLD       0.20000
# XLK       0.02642
# SPY       0.27358
# TAIL.K    0.50000
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2016-04-09 00:00:00 to 2018-04-08 00:00:00
# SOLVER: ECOS
# Market Momentum for 2018-04-08 00:00:00: 0.4105064031047134
# GLD       0.20000
# XLK       0.02333
# SPY       0.27667
# TAIL.K    0.50000
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2016-04-16 00:00:00 to 2018-04-15 00:00:00
# SOLVER: ECOS
# Market Momentum for 2018-04-15 00:00:00: 0.5492643501443879
# XLK    0.5
# SPY    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2016-04-23 00:00:00 to 2018-04-22 00:00:00
# SOLVER: ECOS
# ...
# SOLVER: ECOS
# Market Momentum for 2020-07-19 00:00:00: 0.7511632712864679
# XLK    1.0
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2018-07-28 00:00:00 to 2020-07-26 00:00:00
# SOLVER: ECOS
# Market Momentum for 2020-07-26 00:00:00: 0.7329061099542054
# XLK    1.0
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2018-08-04 00:00:00 to 2020-08-02 00:00:00
# SOLVER: ECOS
# Market Momentum for 2020-08-02 00:00:00: 0.6804567851910341
# XLK    1.0
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2018-08-11 00:00:00 to 2020-08-09 00:00:00
# SOLVER: ECOS
# Market Momentum for 2020-08-09 00:00:00: 0.6748587575761202
# XLK    1.0
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2018-08-18 00:00:00 to 2020-08-16 00:00:00
# SOLVER: ECOS
# Market Momentum for 2020-08-16 00:00:00: 0.7093329983508654
# XLK    1.0
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2018-08-25 00:00:00 to 2020-08-23 00:00:00
# SOLVER: ECOS
# Market Momentum for 2020-08-23 00:00:00: 0.791043169847556
# XLK    1.0
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2018-09-01 00:00:00 to 2020-08-30 00:00:00
# SOLVER: ECOS
# Market Momentum for 2020-08-30 00:00:00: 0.924111919448009
# XLK    1.0
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2018-09-08 00:00:00 to 2020-09-06 00:00:00
# SOLVER: ECOS
# Market Momentum for 2020-09-06 00:00:00: 0.894769358330162
# XLK    1.0
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2018-09-15 00:00:00 to 2020-09-13 00:00:00
# SOLVER: ECOS
# Market Momentum for 2020-09-13 00:00:00: 0.6533016344781999
# XLK    1.0
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2018-09-22 00:00:00 to 2020-09-20 00:00:00
# SOLVER: ECOS
# Market Momentum for 2020-09-20 00:00:00: 0.6415354262251817
# XLK    1.0
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2018-09-29 00:00:00 to 2020-09-27 00:00:00
# SOLVER: ECOS
# Market Momentum for 2020-09-27 00:00:00: 0.5317260528467539
# XLK    1.0
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2018-10-06 00:00:00 to 2020-10-04 00:00:00
# SOLVER: ECOS
# Market Momentum for 2020-10-04 00:00:00: 0.5776703471767706
# XLK    1.0
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2018-10-13 00:00:00 to 2020-10-11 00:00:00
# SOLVER: ECOS
# Market Momentum for 2020-10-11 00:00:00: 0.5857789033291889
# XLK    1.0
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2018-10-20 00:00:00 to 2020-10-18 00:00:00
# SOLVER: ECOS
# Market Momentum for 2020-10-18 00:00:00: 0.5897424700491911
# XLK    1.0
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2018-10-27 00:00:00 to 2020-10-25 00:00:00
# SOLVER: ECOS
# Market Momentum for 2020-10-25 00:00:00: 0.5580519688715233
# XLK    1.0
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2018-11-03 00:00:00 to 2020-11-01 00:00:00
# SOLVER: ECOS
# Market Momentum for 2020-11-01 00:00:00: 0.4504930839159236
# GLD       0.2
# XLK       0.3
# TAIL.K    0.5
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2018-11-10 00:00:00 to 2020-11-08 00:00:00
# SOLVER: ECOS
# Market Momentum for 2020-11-08 00:00:00: 0.5074477279447255
# XLK    1.0
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2018-11-17 00:00:00 to 2020-11-15 00:00:00
# SOLVER: ECOS
# Market Momentum for 2020-11-15 00:00:00: 0.6219022434952706
# XLK    1.0
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2018-11-24 00:00:00 to 2020-11-22 00:00:00
# SOLVER: ECOS
# Market Momentum for 2020-11-22 00:00:00: 0.621430485548842
# XLK    1.0
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2018-12-01 00:00:00 to 2020-11-29 00:00:00
# SOLVER: ECOS
# Market Momentum for 2020-11-29 00:00:00: 0.6986921544833686
# XLK    1.0
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2018-12-08 00:00:00 to 2020-12-06 00:00:00
# SOLVER: ECOS
# Market Momentum for 2020-12-06 00:00:00: 0.6900585722329309
# XLK    1.0
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2018-12-15 00:00:00 to 2020-12-13 00:00:00
# SOLVER: ECOS
# Market Momentum for 2020-12-13 00:00:00: 0.6560134218847928
# XLK    1.0
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2018-12-22 00:00:00 to 2020-12-20 00:00:00
# SOLVER: ECOS
# Market Momentum for 2020-12-20 00:00:00: 0.6279028814783786
# XLK    1.0
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2018-12-29 00:00:00 to 2020-12-27 00:00:00
# SOLVER: ECOS
# Market Momentum for 2020-12-27 00:00:00: 0.6466104353972975
# XLK    1.0
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2019-01-05 00:00:00 to 2021-01-03 00:00:00
# SOLVER: ECOS
# Market Momentum for 2021-01-03 00:00:00: 0.7974832699525094
# XLK    1.0
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2019-01-12 00:00:00 to 2021-01-10 00:00:00
# SOLVER: ECOS
# Market Momentum for 2021-01-10 00:00:00: 0.7802604376926283
# XLK    1.0
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2019-01-19 00:00:00 to 2021-01-17 00:00:00
# SOLVER: ECOS
# Market Momentum for 2021-01-17 00:00:00: 0.8844941585063646
# XLK    1.0
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2019-01-26 00:00:00 to 2021-01-24 00:00:00
# SOLVER: ECOS
# Market Momentum for 2021-01-24 00:00:00: 0.9003517124730475
# XLK    1.0
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2019-02-02 00:00:00 to 2021-01-31 00:00:00
# SOLVER: ECOS
# Market Momentum for 2021-01-31 00:00:00: 0.6875974925869255
# XLK    1.0
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2019-02-09 00:00:00 to 2021-02-07 00:00:00
# SOLVER: ECOS
# Market Momentum for 2021-02-07 00:00:00: 0.6896267370094069
# XLK    1.0
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2019-02-16 00:00:00 to 2021-02-14 00:00:00
# SOLVER: ECOS
# Market Momentum for 2021-02-14 00:00:00: 0.7283114065448285
# XLK    1.0
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2019-02-23 00:00:00 to 2021-02-21 00:00:00
# SOLVER: ECOS
# Market Momentum for 2021-02-21 00:00:00: 0.7460016060968608
# XLK    1.0
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2019-03-02 00:00:00 to 2021-02-28 00:00:00
# SOLVER: ECOS
# Market Momentum for 2021-02-28 00:00:00: 0.7270877077887705
# XLK    1.0
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2019-03-09 00:00:00 to 2021-03-07 00:00:00
# SOLVER: ECOS
# Market Momentum for 2021-03-07 00:00:00: 0.6995201232015238
# XLK    1.0
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2019-03-16 00:00:00 to 2021-03-14 00:00:00
# SOLVER: ECOS
# Market Momentum for 2021-03-14 00:00:00: 0.718367049521262
# XLK    1.0
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2019-03-23 00:00:00 to 2021-03-21 00:00:00
# SOLVER: ECOS
# Market Momentum for 2021-03-21 00:00:00: 0.7218111803867531
# XLK    1.0
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2019-03-30 00:00:00 to 2021-03-28 00:00:00
# SOLVER: ECOS
# Market Momentum for 2021-03-28 00:00:00: 0.6740669230583256
# XLK    1.0
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2019-04-06 00:00:00 to 2021-04-04 00:00:00
# SOLVER: ECOS
# Market Momentum for 2021-04-04 00:00:00: 0.8139313910771968
# XLK    1.0
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2019-04-13 00:00:00 to 2021-04-11 00:00:00
# SOLVER: ECOS
# Market Momentum for 2021-04-11 00:00:00: 0.816136116004955
# XLK    1.0
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2019-04-20 00:00:00 to 2021-04-18 00:00:00
# SOLVER: ECOS
# Market Momentum for 2021-04-18 00:00:00: 0.7992570206183987
# XLK    1.0
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2019-04-27 00:00:00 to 2021-04-25 00:00:00
# SOLVER: ECOS
# Market Momentum for 2021-04-25 00:00:00: 0.756427332018211
# XLK    1.0
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2019-05-04 00:00:00 to 2021-05-02 00:00:00
# SOLVER: ECOS
# Market Momentum for 2021-05-02 00:00:00: 0.8213676160368114
# XLK    1.0
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2019-05-11 00:00:00 to 2021-05-09 00:00:00
# SOLVER: ECOS
# Market Momentum for 2021-05-09 00:00:00: 0.804223049421062
# XLK    1.0
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2019-05-18 00:00:00 to 2021-05-16 00:00:00
# SOLVER: ECOS
# Market Momentum for 2021-05-16 00:00:00: 0.7055334315953818
# XLK    1.0
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2019-05-25 00:00:00 to 2021-05-23 00:00:00
# SOLVER: ECOS
# Market Momentum for 2021-05-23 00:00:00: 0.6647545976804354
# XLK    1.0
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2019-06-01 00:00:00 to 2021-05-30 00:00:00
# SOLVER: ECOS
# Market Momentum for 2021-05-30 00:00:00: 0.7343066157399312
# XLK    1.0
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2019-06-08 00:00:00 to 2021-06-06 00:00:00
# SOLVER: ECOS
# Market Momentum for 2021-06-06 00:00:00: 0.698093861957693
# XLK    1.0
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2019-06-15 00:00:00 to 2021-06-13 00:00:00
# SOLVER: ECOS
# Market Momentum for 2021-06-13 00:00:00: 0.6455391246426807
# XLK    1.0
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2019-06-22 00:00:00 to 2021-06-20 00:00:00
# SOLVER: ECOS
# Market Momentum for 2021-06-20 00:00:00: 0.5917782206648259
# XLK    1.0
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2019-06-29 00:00:00 to 2021-06-27 00:00:00
# SOLVER: ECOS
# Market Momentum for 2021-06-27 00:00:00: 0.6429511463558899
# XLK    1.0
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2019-07-06 00:00:00 to 2021-07-04 00:00:00
# SOLVER: ECOS
# Market Momentum for 2021-07-04 00:00:00: 0.6445781245302675
# XLK    1.0
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2019-07-13 00:00:00 to 2021-07-11 00:00:00
# SOLVER: ECOS
# Market Momentum for 2021-07-11 00:00:00: 0.6610056905128223
# XLK    1.0
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2019-07-20 00:00:00 to 2021-07-18 00:00:00
# SOLVER: ECOS
# Market Momentum for 2021-07-18 00:00:00: 0.7879846926153007
# XLK    1.0
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2019-07-27 00:00:00 to 2021-07-25 00:00:00
# SOLVER: ECOS
# Market Momentum for 2021-07-25 00:00:00: 0.6530413179574504
# XLK    1.0
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2019-08-03 00:00:00 to 2021-08-01 00:00:00
# SOLVER: ECOS
# Market Momentum for 2021-08-01 00:00:00: 0.6550577383222846
# XLK    1.0
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2019-08-10 00:00:00 to 2021-08-08 00:00:00
# SOLVER: ECOS
# Market Momentum for 2021-08-08 00:00:00: 0.6389668239207233
# XLK    1.0
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2019-08-17 00:00:00 to 2021-08-15 00:00:00
# SOLVER: ECOS
# Market Momentum for 2021-08-15 00:00:00: 0.6905521748489003
# XLK    1.0
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2019-08-24 00:00:00 to 2021-08-22 00:00:00
# SOLVER: ECOS
# Market Momentum for 2021-08-22 00:00:00: 0.6380976539499343
# XLK    1.0
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2019-08-31 00:00:00 to 2021-08-29 00:00:00
# SOLVER: ECOS
# Market Momentum for 2021-08-29 00:00:00: 0.6644257165584326
# XLK    1.0
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2019-09-07 00:00:00 to 2021-09-05 00:00:00
# SOLVER: ECOS
# Market Momentum for 2021-09-05 00:00:00: 0.6570092008920398
# XLK    1.0
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2019-09-14 00:00:00 to 2021-09-12 00:00:00
# SOLVER: ECOS
# Market Momentum for 2021-09-12 00:00:00: 0.6266809136706399
# XLK    1.0
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2019-09-21 00:00:00 to 2021-09-19 00:00:00
# SOLVER: ECOS
# Market Momentum for 2021-09-19 00:00:00: 0.5778380631002442
# XLK    1.0
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Starting calculating weights for period from: 2019-09-28 00:00:00 to 2021-09-26 00:00:00
# SOLVER: ECOS
# Market Momentum for 2021-09-26 00:00:00: 0.5719665350766936
# XLK    1.0
# dtype: float64
# -------------------------------------------------------------
#
#
#
# Optimization Finished!
#
# Errors for portfolios: []

# %%
print(strategies_dict)
# Out:
# {'minVol': 2015-01-05    1.000000
# 2015-01-06    1.008126
# 2015-01-07    1.009198
# 2015-01-08    1.007584
# 2015-01-09    1.013600
#                 ...
# 2021-09-24    2.006317
# 2021-09-27    1.993717
# 2021-09-28    1.944081
# 2021-09-29    1.944491
# 2021-09-30    1.925626
# Length: 1698, dtype: float64, 'maxSharpe': 2015-01-05    1.000000
# 2015-01-06    1.008247
# 2015-01-07    1.009504
# 2015-01-08    1.007693
# 2015-01-09    1.013485
#                 ...
# 2021-09-24    2.415158
# 2021-09-27    2.391732
# 2021-09-28    2.320838
# 2021-09-29    2.317910
# 2021-09-30    2.301266
# Length: 1698, dtype: float64}

# %%
v_stratDf = pd.DataFrame.from_dict(strategies_dict)
print(v_stratDf)

# get the bechmark series
p_folderName='US_benchmarks'    # name of folder where the database is kept 
v_benchList = Stock.getStocksFromFiles(p_database='eikon', p_number=None, p_exchange=p_folderName, p_shuffle=False)
v_benchPricesDf = Stock.getAssetsAggregatedDf(v_benchList)  
v_benchPricesDf = v_benchPricesDf.loc[v_stratDf.index[0]:v_stratDf.index[-1]]
v_benchPricesDf = v_benchPricesDf / v_benchPricesDf.iloc[0]

# insert benchmark into the dataFrame of all strategies
v_stratDf = pd.concat([v_stratDf, v_benchPricesDf], axis=1)

# plot curves for the best strategies
#v_stratDf = v_stratDf.rebase(1)
strDateFrom = v_dateFrom.strftime('%Y-%m-%d')
strDateTo = v_dateTo.strftime('%Y-%m-%d')
graphTitle = f'Comparison of the best strategies from {strDateFrom} to {strDateTo}'
v_stratDf.plot(figsize=(17,8))
# Out:
#               minVol  maxSharpe
# 2015-01-05  1.000000   1.000000
# 2015-01-06  1.008126   1.008247
# 2015-01-07  1.009198   1.009504
# 2015-01-08  1.007584   1.007693
# 2015-01-09  1.013600   1.013485
# ...              ...        ...
# 2021-09-24  2.006317   2.415158
# 2021-09-27  1.993717   2.391732
# 2021-09-28  1.944081   2.320838
# 2021-09-29  1.944491   2.317910
# 2021-09-30  1.925626   2.301266
#
# [1698 rows x 2 columns]

# %%
# calculating the stats for the best strategies 
statsStrat = v_stratDf.calc_stats()
statsStrat.display()
# Out:
# /Users/crislcastro/opt/anaconda3/lib/python3.7/site-packages/ffn/core.py:2163: RuntimeWarning: divide by zero encountered in true_divide
#   res = np.divide(er.mean(), std)
# Stat                 minVol      maxSharpe    SPY
# -------------------  ----------  -----------  ----------
# Start                2015-01-05  2015-01-05   2015-01-05
# End                  2021-09-30  2021-09-30   2021-09-30
# Risk-free rate       0.00%       0.00%        0.00%
#
# Total Return         92.56%      130.13%      112.74%
# Daily Sharpe         0.81        0.89         0.72
# Daily Sortino        1.21        1.36         1.07
# CAGR                 10.22%      13.17%       11.86%
# Max Drawdown         -14.87%     -14.68%      -34.10%
# Calmar Ratio         0.69        0.90         0.35
#
# MTD                  -5.48%      -6.01%       -4.97%
# 3m                   0.70%       1.12%        0.25%
# 6m                   11.48%      14.22%       8.72%
# YTD                  14.91%      14.84%       14.78%
# 1Y                   20.52%      19.55%       28.14%
# 3Y (ann.)            16.43%      20.40%       13.74%
# 5Y (ann.)            14.74%      18.40%       14.69%
# 10Y (ann.)           -           -            -
# Since Incep. (ann.)  10.22%      13.17%       11.86%
#
# Daily Sharpe         0.81        0.89         0.72
# Daily Sortino        1.21        1.36         1.07
# Daily Mean (ann.)    10.60%      13.54%       12.82%
# Daily Vol (ann.)     13.13%      15.18%       17.88%
# Daily Skew           -1.00       -0.86        -0.72
# Daily Kurt           5.18        4.37         17.14
# Best Day             2.82%       3.40%        9.06%
# Worst Day            -5.75%      -5.73%       -10.94%
#
# Monthly Sharpe       0.85        0.95         0.86
# Monthly Sortino      1.54        1.81         1.49
# Monthly Mean (ann.)  9.90%       12.83%       12.61%
# Monthly Vol (ann.)   11.68%      13.50%       14.62%
# Monthly Skew         -0.37       -0.23        -0.43
# Monthly Kurt         0.04        0.02         1.62
# Best Month           9.42%       11.88%       12.70%
# Worst Month          -7.60%      -8.66%       -13.00%
#
# Yearly Sharpe        1.33        1.30         1.17
# Yearly Sortino       inf         inf          5.30
# Yearly Mean          12.77%      16.17%       13.73%
# Yearly Vol           9.64%       12.42%       11.71%
# Yearly Skew          0.78        0.91         -0.85
# Yearly Kurt          0.15        0.73         1.77
# Best Year            28.58%      37.12%       28.79%
# Worst Year           2.83%       4.01%        -6.35%
#
# Avg. Drawdown        -1.84%      -2.38%       -1.70%
# Avg. Drawdown Days   29.47       30.69        18.00
# Avg. Up Month        2.96%       3.46%        3.08%
# Avg. Down Month      -2.55%      -2.92%       -3.68%
# Win Year %           100.00%     100.00%      83.33%
# Win 12m %            78.57%      90.00%       88.57%

# %%
### ----------- in case of Errors in the optimization process, try with alternative solvers
#solversList = ['OSQP', 'SCS']

#i_solver = 'OSQP' 
#i_method = 'MaxSharpe'
#i_bound = 0.1

#v_bounds = (0, i_bound)
        
#if i_method == 'minVolatility':
#    i_metStr = 'minVol'
#elif i_method == 'maxSharpe':
#    i_metStr = i_method
#keyName =  f'{i_metStr}_{i_bound}'

#v_errors.pop(0) # remove the first item from v_errors

#try:
#    print(f'--------------------------------------------------------------\n')
#    print(f'Starting Backtesting from {v_dateFrom} to {v_dateTo}\n')
#    print(f'Strategy Name: {keyName} - Solver: {i_solver} \n')
#    print(f'--------------------------------------------------------------\n')

#    v_cumReturnsSeries = PyPortfolioOptimize(p_assets=v_assetsList, 
#                                             p_compositionsSeries=v_compositionsSeries,
#                                             p_dateFrom=v_dateFrom,
#                                             p_dateTo=v_dateTo,
#                                             p_selectByComposition=v_selectByComposition,
#                                             p_selectByReturn=v_selectByReturn,
#                                             p_minAssetLength = v_minAssetLength,  
#                                             verbose=True,
#                                             p_inSamplePeriod=v_inSamplePeriod,
#                                             p_rollingPeriod=v_rollingPeriod,
#                                             p_method=i_method,
#                                             p_bounds=v_bounds,
#                                             p_solver = i_solver)
#    if optimization was successfull, then insert strategy's cumulative returns into dict 
#    strategies_dict[keyName] = v_cumReturnsSeries
    
#except:
#    traceback.print_exc()
#    print(f'Error for {keyName}')
#    v_errors.append(keyName)
        
        
#print(f'Errors for portfolios: {v_errors}')
    
#if len(v_errors) == 0: 
    #save_to_pickle(v_savingPath, strategies_dict)
